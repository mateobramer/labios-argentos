# %% [markdown]
# # 09 - Preprocessing variant review
#
# Revision de `lower_face_resized96` antes de generar ROIs full en VM.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, Markdown, display
from visual_preprocessing.src.preprocessing_variant_review import (
    cargar_smoke, cargar_full, full_generation_status, pending_message,
    preview_groups, preview_paths, sample_table, smoke_decision, smoke_status,
)
pd.set_option("display.max_colwidth", 160)
smoke = cargar_smoke()
full = cargar_full()
status = smoke_status(smoke)
decision = smoke_decision(smoke)

# %% [markdown]
# ## Smoke readiness

# %%
display(pd.DataFrame([{"variant": "lower_face_resized96", "smoke_status": status, "decision": decision, "clips": len(smoke)}]))
display(Markdown(pending_message(status, decision)))
# Out:
#                 variant smoke_status                   decision  clips
# 0  lower_face_resized96    generated  READY_FOR_FULL_GENERATION     20
# Smoke generado: revisar grillas y shapes antes de VM full.

# %% [markdown]
# ## Smoke manifest

# %%
display(sample_table(smoke).head(25))
# Out:
#                                           source_id       clip current_shape  \
# 0   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0001     112x96x96
# 1   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0002      81x96x96
# 2   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0003     147x96x96
# 3   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0004     139x96x96
# 4   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0005     137x96x96
# 5   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0006     158x96x96
# 6   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0007     242x96x96
# 7   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0008     154x96x96
# 8   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0009     160x96x96
# 9   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0010     220x96x96
# 10  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0011     136x96x96
# 11  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0012     112x96x96
# 12  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0013     156x96x96
# 13  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0014     110x96x96
# 14  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0015     165x96x96
# 15  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0016     160x96x96
# 16  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0017     140x96x96
# 17  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0018     127x96x96
# 18  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0019      99x96x96
# 19  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0020     119x96x96
#
#    variant_shape  dtype  frame_count status  reason
# 0                 uint8          112     ok     NaN
# 1                 uint8           81     ok     NaN
# 2                 uint8          147     ok     NaN
# 3                 uint8          139     ok     NaN
# 4                 uint8          137     ok     NaN
# 5                 uint8          158     ok     NaN
# 6                 uint8          242     ok     NaN
# 7                 uint8          154     ok     NaN
# 8                 uint8          160     ok     NaN
# 9                 uint8          220     ok     NaN
# 10                uint8          136     ok     NaN
# 11                uint8          112     ok     NaN
# 12                uint8          156     ok     NaN
# 13                uint8          110     ok     NaN
# 14                uint8          165     ok     NaN
# 15                uint8          160     ok     NaN
# 16                uint8          140     ok     NaN
# 17                uint8          127     ok     NaN
# 18                uint8           99     ok     NaN
# 19                uint8          119     ok     NaN

# %% [markdown]
# ## Full generation manifest

# %%
display(full_generation_status(full))
if not full.empty:
    display(full.head(20))
# Out:
#    full_rows    ok  failed  blocked status
# 0       5950  5950       0        0  ready
#                                           source_id       clip  \
# 0   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0001
# 1   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0002
# 2   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0003
# 3   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0004
# 4   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0005
# 5   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0006
# 6   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0007
# 7   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0008
# 8   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0009
# 9   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0010
# 10  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0011
# 11  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0012
# 12  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0013
# 13  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0014
# 14  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0015
# 15  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0016
# 16  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0017
# 17  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0018
# 18  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0019
# 19  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0020
#
#                                                                         original_roi_path  \
# 0   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0001.npz
# 1   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0002.npz
# 2   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0003.npz
# 3   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0004.npz
# 4   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0005.npz
# 5   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0006.npz
# 6   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0007.npz
# 7   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0008.npz
# 8   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0009.npz
# 9   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0010.npz
# 10  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0011.npz
# 11  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0012.npz
# 12  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0013.npz
# 13  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0014.npz
# 14  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0015.npz
# 15  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0016.npz
# 16  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0017.npz
# 17  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0018.npz
# 18  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0019.npz
# 19  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0020.npz
#
#                                                                                                         variant_roi_path  \
# 0   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0001.npz
# 1   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0002.npz
# 2   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0003.npz
# 3   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0004.npz
# 4   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0005.npz
# 5   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0006.npz
# 6   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0007.npz
# 7   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0008.npz
# 8   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0009.npz
# 9   evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0010.npz
# 10  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0011.npz
# 11  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0012.npz
# 12  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0013.npz
# 13  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0014.npz
# 14  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0015.npz
# 15  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0016.npz
# 16  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0017.npz
# 17  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0018.npz
# 18  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0019.npz
# 19  evaluation/outputs/batch_vsr/rois_lower_face_resized96/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0020.npz
#
#                  variant      shape  dtype status reason
# 0   lower_face_resized96  112x96x96  uint8     ok    NaN
# 1   lower_face_resized96   81x96x96  uint8     ok    NaN
# 2   lower_face_resized96  147x96x96  uint8     ok    NaN
# 3   lower_face_resized96  139x96x96  uint8     ok    NaN
# 4   lower_face_resized96  137x96x96  uint8     ok    NaN
# 5   lower_face_resized96  158x96x96  uint8     ok    NaN
# 6   lower_face_resized96  242x96x96  uint8     ok    NaN
# 7   lower_face_resized96  154x96x96  uint8     ok    NaN
# 8   lower_face_resized96  160x96x96  uint8     ok    NaN
# 9   lower_face_resized96  220x96x96  uint8     ok    NaN
# 10  lower_face_resized96  136x96x96  uint8     ok    NaN
# 11  lower_face_resized96  112x96x96  uint8     ok    NaN
# 12  lower_face_resized96  156x96x96  uint8     ok    NaN
# 13  lower_face_resized96  110x96x96  uint8     ok    NaN
# 14  lower_face_resized96  165x96x96  uint8     ok    NaN
# 15  lower_face_resized96  160x96x96  uint8     ok    NaN
# 16  lower_face_resized96  140x96x96  uint8     ok    NaN
# 17  lower_face_resized96  127x96x96  uint8     ok    NaN
# 18  lower_face_resized96   99x96x96  uint8     ok    NaN
# 19  lower_face_resized96  119x96x96  uint8     ok    NaN

# %% [markdown]
# ## Preview paths

# %%
groups = preview_groups()
display(groups.head(20))
# Out:
#                                                         sample  \
# 0   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001
# 1   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002
# 2   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003
# 3   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0004
# 4   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0005
# 5   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0006
# 6   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0007
# 7   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0008
# 8   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0009
# 9   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0010
# 10  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0011
# 11  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0012
# 12  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0013
# 13  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0014
# 14  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0015
# 15  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0016
# 16  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0017
# 17  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0018
# 18  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0019
# 19  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0020
#
#                                                                                                                                                   current_roi_96x96  \
# 0   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__current_g...
# 1   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002__current_g...
# 2   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003__current_g...
# 3   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0004__current_g...
# 4   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0005__current_g...
# 5   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0006__current_g...
# 6   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0007__current_g...
# 7   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0008__current_g...
# 8   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0009__current_g...
# 9   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0010__current_g...
# 10  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0011__current_g...
# 11  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0012__current_g...
# 12  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0013__current_g...
# 13  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0014__current_g...
# 14  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0015__current_g...
# 15  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0016__current_g...
# 16  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0017__current_g...
# 17  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0018__current_g...
# 18  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0019__current_g...
# 19  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0020__current_g...
#
#                                                                                                                                                lower_face_resized96  \
# 0   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__lower_fac...
# 1   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002__lower_fac...
# 2   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003__lower_fac...
# 3   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0004__lower_fac...
# 4   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0005__lower_fac...
# 5   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0006__lower_fac...
# 6   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0007__lower_fac...
# 7   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0008__lower_fac...
# 8   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0009__lower_fac...
# 9   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0010__lower_fac...
# 10  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0011__lower_fac...
# 11  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0012__lower_fac...
# 12  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0013__lower_fac...
# 13  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0014__lower_fac...
# 14  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0015__lower_fac...
# 15  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0016__lower_fac...
# 16  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0017__lower_fac...
# 17  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0018__lower_fac...
# 18  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0019__lower_fac...
# 19  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0020__lower_fac...
#
#                                                                                                                                                        side_by_side
# 0   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__side_by_s...
# 1   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002__side_by_s...
# 2   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003__side_by_s...
# 3   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0004__side_by_s...
# 4   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0005__side_by_s...
# 5   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0006__side_by_s...
# 6   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0007__side_by_s...
# 7   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0008__side_by_s...
# 8   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0009__side_by_s...
# 9   /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0010__side_by_s...
# 10  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0011__side_by_s...
# 11  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0012__side_by_s...
# 12  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0013__side_by_s...
# 13  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0014__side_by_s...
# 14  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0015__side_by_s...
# 15  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0016__side_by_s...
# 16  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0017__side_by_s...
# 17  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0018__side_by_s...
# 18  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0019__side_by_s...
# 19  /home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0020__side_by_s...

# %% [markdown]
# ## Preview render

# %%
paths = preview_paths()
for path in paths["path"].head(3) if not paths.empty else []:
    display(Markdown(f"`{path}`"))
    display(Image(filename=path))
# Out:
# `/home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__current_grid.png`
# `/home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__lower_face_resized96_grid.png`
# `/home/bianc/labios-argentos/evaluation/outputs/batch_vsr/preprocessing_variant_preview/LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001__side_by_side.png`
