# %% [markdown]
# # Preprocessing Variant Review
#
# Revision visual de `lower_face_resized96`. Funciona aunque los ROIs variant full no existan todavia.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, Markdown, display

from evaluation.src.preprocessing_variant_review import (
    cargar_smoke,
    pending_message,
    preview_groups,
    preview_paths,
    sample_table,
    smoke_decision,
    smoke_status,
)

pd.set_option("display.max_colwidth", 160)
smoke = cargar_smoke()
status = smoke_status(smoke)
decision = smoke_decision(smoke)

# %% [markdown]
# ## Estado del smoke

# %%
display(pd.DataFrame([{"smoke_status": status, "decision": decision, "clips": len(smoke)}]))
display(Markdown(pending_message(status, decision)))
# Out:
#   smoke_status                   decision  clips
# 0    generated  READY_FOR_FULL_GENERATION     20
# Smoke generado: revisar grillas y shapes antes de VM full.

# %% [markdown]
# ## Clips sampleados

# %%
display(sample_table(smoke))
# Out:
#                                           source_id       clip current_shape  \
# 0   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0001     112x96x96
# 1   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0002      81x96x96
# 2   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0003     147x96x96
# 3   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0004     139x96x96
# 4   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0005     137x96x96
# 5   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0006     158x96x96
# 6   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0007     242x96x96
# 7   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0008     154x96x96
# 8   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0009     160x96x96
# 9   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0010     220x96x96
# 10  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0011     136x96x96
# 11  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0012     112x96x96
# 12  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0013     156x96x96
# 13  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0014     110x96x96
# 14  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0015     165x96x96
# 15  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0016     160x96x96
# 16  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0017     140x96x96
# 17  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0018     127x96x96
# 18  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0019      99x96x96
# 19  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0020     119x96x96
#
#    variant_shape  dtype  frame_count status  reason
# 0      112x96x96  uint8          112     ok     NaN
# 1       81x96x96  uint8           81     ok     NaN
# 2      147x96x96  uint8          147     ok     NaN
# 3      139x96x96  uint8          139     ok     NaN
# 4      137x96x96  uint8          137     ok     NaN
# 5      158x96x96  uint8          158     ok     NaN
# 6      242x96x96  uint8          242     ok     NaN
# 7      154x96x96  uint8          154     ok     NaN
# 8      160x96x96  uint8          160     ok     NaN
# 9      220x96x96  uint8          220     ok     NaN
# 10     136x96x96  uint8          136     ok     NaN
# 11     112x96x96  uint8          112     ok     NaN
# 12     156x96x96  uint8          156     ok     NaN
# 13     110x96x96  uint8          110     ok     NaN
# 14     165x96x96  uint8          165     ok     NaN
# 15     160x96x96  uint8          160     ok     NaN
# 16     140x96x96  uint8          140     ok     NaN
# 17     127x96x96  uint8          127     ok     NaN
# 18      99x96x96  uint8           99     ok     NaN
# 19     119x96x96  uint8          119     ok     NaN

# %% [markdown]
# ## Contact sheets / previews

# %%
previews = preview_paths()
groups = preview_groups()
if previews.empty:
    display(Markdown("Pendiente de VM: falta generar lower_face_resized96."))
else:
    display(groups.head(20))
    for _, row in groups.head(3).iterrows():
        display(Markdown(f"### {row['sample']}"))
        for label, column in [
            ("Current ROI 96x96", "current_roi_96x96"),
            ("lower_face_resized96", "lower_face_resized96"),
            ("Side-by-side", "side_by_side"),
        ]:
            path = row.get(column)
            if isinstance(path, str) and path:
                display(Markdown(f"**{label}**"))
                display(Image(filename=path))
# Out:
#                                                         sample  \
# 0   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001
# 1   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002
# 2   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003
# 3   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0004
# 4   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0005
# 5   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0006
# 6   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0007
# 7   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0008
# 8   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0009
# 9   LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0010
# 10  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0011
# 11  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0012
# 12  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0013
# 13  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0014
# 14  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0015
# 15  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0016
# 16  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0017
# 17  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0018
# 18  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0019
# 19  LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0020
#
#                                                                                                                                                   current_roi_96x96  \
# 0   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 1   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 2   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 3   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 4   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 5   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 6   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 7   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 8   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 9   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 10  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 11  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 12  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 13  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 14  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 15  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 16  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 17  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 18  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 19  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
#
#                                                                                                                                                lower_face_resized96  \
# 0   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 1   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 2   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 3   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 4   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 5   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 6   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 7   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 8   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 9   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 10  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 11  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 12  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 13  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 14  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 15  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 16  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 17  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 18  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 19  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
#
#                                                                                                                                                        side_by_side
# 0   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 1   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 2   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 3   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 4   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 5   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 6   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 7   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 8   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 9   C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 10  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 11  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 12  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 13  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 14  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 15  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 16  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 17  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 18  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# 19  C:\Users\bianc\NLP Natural Language Processing\labios-argentos\evaluation\outputs\batch_vsr\preprocessing_variant_preview\LE_DIJE_QUE_SOY_ARGENTINO_-_Story_...
# ### LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0001
# **Current ROI 96x96**
# **lower_face_resized96**
# **Side-by-side**
# ### LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0002
# **Current ROI 96x96**
# **lower_face_resized96**
# **Side-by-side**
# ### LE_DIJE_QUE_SOY_ARGENTINO_-_Story_Time_-_CAP_91__clip_0003
# **Current ROI 96x96**
# **lower_face_resized96**
# **Side-by-side**
