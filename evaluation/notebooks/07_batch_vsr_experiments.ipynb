# %% [markdown]
# # Batch VSR E0-E4
#
# Tablero de preparacion para los experimentos batch. No entrena modelos, no crea VM y no corre GCP.

# %%
import pandas as pd
from IPython.display import Markdown, display

from evaluation.src.batch_vsr_notebook import (
    cargar_configs,
    preprocessing_smoke,
    resultados,
    tamanos_experimentos,
    transcript_asr2,
    transcript_candidates,
    transcript_changes,
    transcript_disagreement,
    transcript_policy,
    transcript_summary,
)

pd.set_option("display.max_colwidth", 140)

# %% [markdown]
# ## Matriz E0-E4

# %% [markdown]
# Revisiones complementarias: `../data_cleaning/notebooks/08_transcript_cleaning_review.ipynb` para cambios/candidatos de transcripts y `../visual_preprocessing/notebooks/09_preprocessing_variant_review.ipynb` para smoke/previews de `lower_face_resized96`.

# %%
configs = cargar_configs()
configs[["experiment", "status", "visual_cleaning", "transcript_variant", "preprocessing_variant", "blocked_reason"]]
# Out:
#                        experiment                  status visual_cleaning  \
# 0            E0_baseline_original                   ready            none
# 1               E1_visual_cleaned                   ready    conservative
# 2  E2_transcript_cleaned_stronger    blocked_missing_asr2            none
# 3        E3_preprocessing_variant  ready_after_generation            none
# 4                 E4_all_combined  ready_after_generation    conservative
#
#             transcript_variant preprocessing_variant  \
# 0                      current               current
# 1                      current               current
# 2  transcript_cleaned_stronger               current
# 3                      current  lower_face_resized96
# 4                      current  lower_face_resized96
#
#                                                                                     blocked_reason
# 0
# 1
# 2                                             falta ASR2 usable; no entrenar E2 como mejora fuerte
# 3  generar ROIs lower_face_resized96 en VM: evaluation\outputs\batch_vsr\rois_lower_face_resized96
# 4  generar ROIs lower_face_resized96 en VM: evaluation\outputs\batch_vsr\rois_lower_face_resized96

# %%
tamanos_experimentos(configs)
# Out:
#                        experiment  train  val  test
# 0            E0_baseline_original   4826  466   658
# 1               E1_visual_cleaned   4623  466   658
# 2  E2_transcript_cleaned_stronger   4826  466   658
# 3        E3_preprocessing_variant   4826  466   658
# 4                 E4_all_combined   4623  466   658

# %% [markdown]
# ## Transcript cleaning

# %%
changes = transcript_changes()
candidates = transcript_candidates()
policy = transcript_policy()
asr2 = transcript_asr2()
disagreement = transcript_disagreement()
display(transcript_summary(changes, candidates, policy, asr2, disagreement))
if changes.empty:
    display(Markdown("**Pendiente:** no existe `transcript_cleaning_changes.csv`."))
else:
    display(changes[changes["changed"].astype(str).str.lower() == "true"].head(10))
if not disagreement.empty:
    display(disagreement.groupby("disagreement_level").size().rename("clips").reset_index())
# Out:
#    transcripts  changed  unchanged  asr2_ok  disagreement_high  \
# 0         5950       52       5898        0                  0
#
#    replacement_candidates  auto_replacements  questionable  bad_candidate  \
# 0                      48                  0            48              0
#
#                decision
# 0  BLOCKED_MISSING_ASR2
#                                                source_id       clip  \
# 12       LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0013
# 69       LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0070
# 398   ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -  clip_0286
# 492   ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -  clip_0380
# 832          ANÉCDOTA VIAJE MUNDIAL BRASIL 2014  parte 1  clip_0191
# 1014   AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A  clip_0056
# 1113   AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A  clip_0158
# 1119   AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A  clip_0164
# 1125   AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A  clip_0170
# 1145   AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A  clip_0192
#
#                                                                                                                                     original_path  \
# 12    C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0013...
# 69    C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0070...
# 398   C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -\clip_0...
# 492   C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -\clip_0...
# 832      C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\ANÉCDOTA VIAJE MUNDIAL BRASIL 2014  parte 1\clip_0191.txt
# 1014  C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_00...
# 1113  C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_01...
# 1119  C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_01...
# 1125  C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_01...
# 1145  C:\Users\bianc\NLP Natural Language Processing\labios-argentos-pr24\data\clips\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_01...
#
#                                                                                                                     cleaned_path  \
# 12       evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0013.txt
# 69       evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0070.txt
# 398   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -\clip_0286.txt
# 492   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\ME ACUSARON DE BRUJA Y ME TUVE QUE IR DEL PUEBLO -\clip_0380.txt
# 832          evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\ANÉCDOTA VIAJE MUNDIAL BRASIL 2014  parte 1\clip_0191.txt
# 1014   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_0056.txt
# 1113   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_0158.txt
# 1119   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_0164.txt
# 1125   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_0170.txt
# 1145   evaluation\outputs\batch_vsr\transcripts_cleaned_stronger\AZZARO REACCIÓN - RIVER, A LA FINAL LE GANÓ 1-0 A\clip_0192.txt
#
#                                                                                                           original_text  \
# 12     tengo varios amigos que viven en montreal especialmente en montreal  especialmente durante el verano en montreal
# 69                                        que lindo verte aca ah leo     le respondo a esta pregunta a sebastian aguero
# 398                                                                    yo marcela tauro todo jugo jugo   con esa carita
# 492                                                    claro esta tu vida  vieja y enterrada tus ancestros te la rebaja
# 832                                         no se fala fala no se no se  no digo amigo en que momento entramos a brasil
# 1014  es muy dificil       es mucha ventaja es mucha ventaja lo del arbitro fue realmente impresentable en esa decision
# 1113                                                   a lo bueno no le sirve no le sirve     a los buenos no les sirve
# 1119      hace cuatro meses estaba con el boleto a santiago del estero y que le importa   que me importaba la mitologia
# 1125                                                   refundemos river pero pero           y hoy goza de las mieles de
# 1145                                               de las circunstancias venga      merecidisima clasificacion de river
#
#       asr2_text  \
# 12          NaN
# 69          NaN
# 398         NaN
# 492         NaN
# 832         NaN
# 1014        NaN
# 1113        NaN
# 1119        NaN
# 1125        NaN
# 1145        NaN
#
#                                                                                                          cleaned_text  \
# 12    tengo varios amigos que viven en montreal especialmente en montreal especialmente durante el verano en montreal
# 69                                          que lindo verte aca ah leo le respondo a esta pregunta a sebastian aguero
# 398                                                                    yo marcela tauro todo jugo jugo con esa carita
# 492                                                   claro esta tu vida vieja y enterrada tus ancestros te la rebaja
# 832                                        no se fala fala no se no se no digo amigo en que momento entramos a brasil
# 1014      es muy dificil es mucha ventaja es mucha ventaja lo del arbitro fue realmente impresentable en esa decision
# 1113                                                     a lo bueno no le sirve no le sirve a los buenos no les sirve
# 1119      hace cuatro meses estaba con el boleto a santiago del estero y que le importa que me importaba la mitologia
# 1125                                                           refundemos river pero pero y hoy goza de las mieles de
# 1145                                                  de las circunstancias venga merecidisima clasificacion de river
#
#       changed          change_type                  evidence confidence  \
# 12       True  space_normalization  espacios multiples/strip       high
# 69       True  space_normalization  espacios multiples/strip       high
# 398      True  space_normalization  espacios multiples/strip       high
# 492      True  space_normalization  espacios multiples/strip       high
# 832      True  space_normalization  espacios multiples/strip       high
# 1014     True  space_normalization  espacios multiples/strip       high
# 1113     True  space_normalization  espacios multiples/strip       high
# 1119     True  space_normalization  espacios multiples/strip       high
# 1125     True  space_normalization  espacios multiples/strip       high
# 1145     True  space_normalization  espacios multiples/strip       high
#
#       auto_applied asr_disagreement_level
# 12            True                blocked
# 69            True                    NaN
# 398           True                    NaN
# 492           True                    NaN
# 832           True                    NaN
# 1014          True                    NaN
# 1113          True                    NaN
# 1119          True                    NaN
# 1125          True                    NaN
# 1145          True                    NaN
#   disagreement_level  clips
# 0            blocked     20

# %% [markdown]
# ## Preprocessing smoke

# %%
smoke = preprocessing_smoke()
if smoke.empty:
    display(Markdown("**Pendiente:** no existe manifest de smoke de preprocessing."))
else:
    display(smoke)
# Out:
#                                           source_id       clip  \
# 0   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0001
# 1   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0002
# 2   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0003
# 3   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0004
# 4   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0005
# 5   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0006
# 6   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0007
# 7   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0008
# 8   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0009
# 9   LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0010
# 10  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0011
# 11  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0012
# 12  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0013
# 13  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0014
# 14  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0015
# 15  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0016
# 16  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0017
# 17  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0018
# 18  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0019
# 19  LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91  clip_0020
#
#                                                                         original_roi_path  \
# 0   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0001.npz
# 1   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0002.npz
# 2   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0003.npz
# 3   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0004.npz
# 4   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0005.npz
# 5   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0006.npz
# 6   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0007.npz
# 7   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0008.npz
# 8   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0009.npz
# 9   data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0010.npz
# 10  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0011.npz
# 11  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0012.npz
# 12  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0013.npz
# 13  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0014.npz
# 14  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0015.npz
# 15  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0016.npz
# 16  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0017.npz
# 17  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0018.npz
# 18  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0019.npz
# 19  data/processed/lip_rois/LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91/clip_0020.npz
#
#                                                                                                           variant_roi_path  \
# 0   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0001.npz
# 1   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0002.npz
# 2   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0003.npz
# 3   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0004.npz
# 4   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0005.npz
# 5   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0006.npz
# 6   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0007.npz
# 7   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0008.npz
# 8   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0009.npz
# 9   evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0010.npz
# 10  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0011.npz
# 11  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0012.npz
# 12  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0013.npz
# 13  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0014.npz
# 14  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0015.npz
# 15  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0016.npz
# 16  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0017.npz
# 17  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0018.npz
# 18  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0019.npz
# 19  evaluation\outputs\batch_vsr\preprocessing_variant_smoke\LE DIJE QUE SOY ARGENTINO - Story Time - CAP 91\clip_0020.npz
#
#                  variant      shape  dtype status  reason
# 0   lower_face_resized96  112x96x96  uint8     ok     NaN
# 1   lower_face_resized96   81x96x96  uint8     ok     NaN
# 2   lower_face_resized96  147x96x96  uint8     ok     NaN
# 3   lower_face_resized96  139x96x96  uint8     ok     NaN
# 4   lower_face_resized96  137x96x96  uint8     ok     NaN
# 5   lower_face_resized96  158x96x96  uint8     ok     NaN
# 6   lower_face_resized96  242x96x96  uint8     ok     NaN
# 7   lower_face_resized96  154x96x96  uint8     ok     NaN
# 8   lower_face_resized96  160x96x96  uint8     ok     NaN
# 9   lower_face_resized96  220x96x96  uint8     ok     NaN
# 10  lower_face_resized96  136x96x96  uint8     ok     NaN
# 11  lower_face_resized96  112x96x96  uint8     ok     NaN
# 12  lower_face_resized96  156x96x96  uint8     ok     NaN
# 13  lower_face_resized96  110x96x96  uint8     ok     NaN
# 14  lower_face_resized96  165x96x96  uint8     ok     NaN
# 15  lower_face_resized96  160x96x96  uint8     ok     NaN
# 16  lower_face_resized96  140x96x96  uint8     ok     NaN
# 17  lower_face_resized96  127x96x96  uint8     ok     NaN
# 18  lower_face_resized96   99x96x96  uint8     ok     NaN
# 19  lower_face_resized96  119x96x96  uint8     ok     NaN

# %% [markdown]
# ## Resultados VSR

# %%
res = resultados()
if res.empty:
    display(Markdown("**Pendiente de VM:** todavia no hay resultados parseados."))
else:
    display(res)
# Out:
#                        experiment   status  rows  wer  cer  \
# 0            E0_baseline_original  pending   NaN  NaN  NaN
# 1               E1_visual_cleaned  pending   NaN  NaN  NaN
# 2  E2_transcript_cleaned_stronger  pending   NaN  NaN  NaN
# 3        E3_preprocessing_variant  pending   NaN  NaN  NaN
# 4                 E4_all_combined  pending   NaN  NaN  NaN
#
#                                                                            reason  \
# 0            falta evaluation\outputs\batch_vsr\raw\E0_baseline_original\test.inf
# 1               falta evaluation\outputs\batch_vsr\raw\E1_visual_cleaned\test.inf
# 2  falta evaluation\outputs\batch_vsr\raw\E2_transcript_cleaned_stronger\test.inf
# 3        falta evaluation\outputs\batch_vsr\raw\E3_preprocessing_variant\test.inf
# 4                 falta evaluation\outputs\batch_vsr\raw\E4_all_combined\test.inf
#
#    output
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
ready = configs[configs["status"] == "ready"]["experiment"].tolist()
after = configs[configs["status"] == "ready_after_generation"]["experiment"].tolist()
blocked = configs[configs["status"].astype(str).str.contains("blocked", case=False, na=False)]["experiment"].tolist()
low_impact = configs[configs["status"].astype(str).str.contains("low_impact", case=False, na=False)]["experiment"].tolist()
msg = (
    f"**Ready:** {ready}  " + "\n"
    f"**Ready after generation:** {after}  " + "\n"
    f"**Blocked:** {blocked}  " + "\n"
    f"**Low impact:** {low_impact}"
)
display(Markdown(msg))
# Out:
# **Ready:** ['E0_baseline_original', 'E1_visual_cleaned']
# **Ready after generation:** ['E3_preprocessing_variant', 'E4_all_combined']
# **Blocked:** ['E2_transcript_cleaned_stronger']
# **Low impact:** []
